# %% [markdown]
# <a href="https://colab.research.google.com/github/Buntariga2545/Project/blob/main/Data_Survey_13_7_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel('/content/drive/My Drive/Paper/Data-Survey-13-7-2023.xlsx')
data
# Out:
#         No               วันที่   เพศ  อายุ  น้ำหนัก  ส่วนสูง        BMI  \
# 0      NaN                  NaN   NaN   NaN      NaN      NaN        NaN
# 1      1.0  2022-12-28 00:00:00   ชาย  27.0     49.0    169.0  17.156262
# 2      2.0  2022-12-28 00:00:00   ชาย  36.0     71.0    175.0  23.183673
# 3      3.0  2022-12-28 00:00:00  หญิง  25.0     89.0    153.0  38.019565
# 4      4.0  2022-12-28 00:00:00   ชาย  29.0     75.0    165.0  27.548209
# ..     ...                  ...   ...   ...      ...      ...        ...
# 189  189.0           13/05/2023   ชาย  37.0     88.0    180.0  27.160494
# 190  190.0           13/05/2023  หญิง  23.0     47.0    159.0  18.591037
# 191  191.0           13/05/2023   ชาย  27.0     47.0    169.0  16.456006
# 192  192.0           13/05/2023   ชาย  57.0     68.0    171.0  23.255019
# 193  193.0           13/05/2023  หญิง  64.0     47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา ค่าที่เครื่องวัดได้  ...  \
# ...

# %%
data = pd.read_excel('/content/drive/My Drive/Paper/Data-Survey-13-7-2023.xlsx', skiprows = 1)
data
# Out:
#      Unnamed: 0           Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0             1  2022-12-28 00:00:00        ชาย          27        49.0
# 1             2  2022-12-28 00:00:00        ชาย          36        71.0
# 2             3  2022-12-28 00:00:00       หญิง          25        89.0
# 3             4  2022-12-28 00:00:00        ชาย          29        75.0
# 4             5  2022-12-28 00:00:00        ชาย          28       118.0
# ..          ...                  ...        ...         ...         ...
# 188         189           13/05/2023        ชาย          37        88.0
# 189         190           13/05/2023       หญิง          23        47.0
# 190         191           13/05/2023        ชาย          27        47.0
# 191         192           13/05/2023        ชาย          57        68.0
# 192         193           13/05/2023       หญิง          64        47.0
#
#      Unnamed: 5  Unnamed: 6            Unnamed: 7 Unnamed: 8  Temp  ...  \
# ...

# %%
data.rename(columns = {'Unnamed: 0' : 'No', 'Unnamed: 1' : 'วันที่', 'Unnamed: 2' : 'เพศ', 'Unnamed: 3' : 'อายุ', 'Unnamed: 4' : 'Weight',
                       'Unnamed: 5' : 'ส่วนสูง', 'Unnamed: 6' : 'BMI', 'Unnamed: 7' : 'พื้นที่ทำแบบสอบถาม', 'Unnamed: 8' : 'เวลา',
                       'Unnamed: 18' : 'Thermal acceptance', 'Unnamed: 26' : 'Thermal sensation Vote'
                       }, inplace = True)
data
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00   ชาย    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00   ชาย    36    71.0    175.0  23.183673
# 2      3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 3      4  2022-12-28 00:00:00   ชาย    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00   ชาย    28   118.0    187.0  33.744173
# ..   ...                  ...   ...   ...     ...      ...        ...
# 188  189           13/05/2023   ชาย    37    88.0    180.0  27.160494
# 189  190           13/05/2023  หญิง    23    47.0    159.0  18.591037
# 190  191           13/05/2023   ชาย    27    47.0    169.0  16.456006
# 191  192           13/05/2023   ชาย    57    68.0    171.0  23.255019
# 192  193           13/05/2023  หญิง    64    47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %%
data.head()
# Out:
#    No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0   1  2022-12-28 00:00:00   ชาย    27    49.0    169.0  17.156262
# 1   2  2022-12-28 00:00:00   ชาย    36    71.0    175.0  23.183673
# 2   3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 3   4  2022-12-28 00:00:00   ชาย    29    75.0    165.0  27.548209
# 4   5  2022-12-28 00:00:00   ชาย    28   118.0    187.0  33.744173
#
#      พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# 0  ภายนอก/ มีหลังคาคลุม  10:55 AM  30.5  ...         2         1        2
# 1  ภายนอก/ มีหลังคาคลุม  10:55 AM  30.5  ...         3         0        5
# 2  ภายนอก/ มีหลังคาคลุม  10:55 AM  30.5  ...         2         0        4
# 3  ภายนอก/ มีหลังคาคลุม  10:55 AM  30.5  ...         3         3        4
# 4  ภายนอก/ มีหลังคาคลุม  10:55 AM  30.5  ...         2         1        4
#
#    ความแรงของแสงแดด  เหงื่อบริเวณผิวหนัง  ความร้อน  ความชื้น.1  กระแสลม.1  \
# ...

# %%
data.tail()
# Out:
#       No      วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 188  189  13/05/2023   ชาย    37    88.0    180.0  27.160494
# 189  190  13/05/2023  หญิง    23    47.0    159.0  18.591037
# 190  191  13/05/2023   ชาย    27    47.0    169.0  16.456006
# 191  192  13/05/2023   ชาย    57    68.0    171.0  23.255019
# 192  193  13/05/2023  หญิง    64    47.0    149.0  21.170218
#
#     พื้นที่ทำแบบสอบถาม   เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# 188        ภายใต้อาคาร  16.26  35.6  ...         3         2        4
# 189        ภายใต้อาคาร  16.26  35.6  ...         3         1        4
# 190        ภายใต้อาคาร  16.26  35.6  ...         4         4        4
# 191        ภายใต้อาคาร  16.26  35.6  ...         3         1        5
# 192        ภายใต้อาคาร  16.26  35.6  ...         3         1        2
#
#      ความแรงของแสงแดด  เหงื่อบริเวณผิวหนัง  ความร้อน  ความชื้น.1  กระแสลม.1  \
# 188                 3                    2        -1           1          0
# ...

# %%
data.columns
# Out:
# Index([                    'No',                 'วันที่',
#                           'เพศ',                   'อายุ',
#                        'Weight',                'ส่วนสูง',
#                           'BMI',     'พื้นที่ทำแบบสอบถาม',
#                          'เวลา',                   'Temp',
#                    'Globe temp',                    '%RH',
#                       'V (m/s)',               'วงเล็บ 1',
#                 'สมการหลัง บวก',               'วงเล็บ 2',
#        'ยกกำลัง 1 ส่วน 4/ 0.25',              'ลบ 273.15',
#            'Thermal acceptance',                       -3,
#                              -2,                       -1,
#                               0,                     '+1',
#                            '+2',                     '+3',
#        'Thermal sensation Vote',               'อุณหภูมิ',
#                      'ความชื้น',                'กระแสลม',
#              'ความแรงของแสงแดด',    'เหงื่อบริเวณผิวหนัง',
# ...

# %%
data.shape
# Out:
# (193, 37)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No                      193 non-null    int64
#  1   วันที่                  193 non-null    object
#  2   เพศ                     193 non-null    object
#  3   อายุ                    193 non-null    int64
#  4   Weight                  192 non-null    float64
#  5   ส่วนสูง                 192 non-null    float64
#  6   BMI                     191 non-null    float64
#  7   พื้นที่ทำแบบสอบถาม      193 non-null    object
#  8   เวลา                    193 non-null    object
#  9   Temp                    193 non-null    float64
#  10  Globe temp              193 non-null    float64
#  11  %RH                     193 non-null    float64
#  12  V (m/s)                 193 non-null    float64
#  13  วงเล็บ 1                193 non-null    int64
# ...

# %%
data.เพศ.value_counts()
# Out:
# ชาย     125
# หญิง     68
# Name: เพศ, dtype: int64

# %%
data.isnull().sum()
# Out:
# No                          0
# วันที่                      0
# เพศ                         0
# อายุ                        0
# Weight                      1
# ส่วนสูง                     1
# BMI                         2
# พื้นที่ทำแบบสอบถาม          0
# เวลา                        0
# Temp                        0
# Globe temp                  0
# %RH                         0
# V (m/s)                     0
# วงเล็บ 1                    0
# สมการหลัง บวก               0
# วงเล็บ 2                    0
# ยกกำลัง 1 ส่วน 4/ 0.25      0
# ลบ 273.15                   0
# Thermal acceptance          0
# -3                        193
# -2                        189
# -1                        154
# 0                         134
# +1                        140
# +2                        171
# +3                        177
# Thermal sensation Vote      0
# อุณหภูมิ                    0
# ความชื้น                    0
# กระแสลม                     0
# ความแรงของแสงแดด            0
# ...

# %%
data.describe()
# Out:
#                No        อายุ      Weight     ส่วนสูง         BMI        Temp  \
# count  193.000000  193.000000  192.000000  192.000000  191.000000  193.000000
# mean    97.000000   30.720207   68.187500  166.463542   24.364324   30.895337
# std     55.858452   11.950177   22.889588   15.515867    7.126414    2.310264
# min      1.000000   20.000000    0.000000    0.000000   16.015625   27.200000
# 25%     49.000000   25.000000   49.000000  158.000000   19.146722   29.100000
# 50%     97.000000   27.000000   63.000000  169.000000   22.230987   30.800000
# 75%    145.000000   36.000000   75.750000  173.250000   27.548209   32.700000
# max    193.000000   70.000000  147.000000  187.000000   48.553310   35.600000
#
#        Globe temp         %RH     V (m/s)      วงเล็บ 1  ...    อุณหภูมิ  \
# count  193.000000  193.000000  193.000000  1.930000e+02  ...  193.000000
# mean    31.533161   48.780829    0.265311  8.621030e+09  ...    2.559585
# ...

# %% [markdown]
# ##drop ข้อมูลที่เป็นค่าว่างจำนวน 3 ค่าออกไปก่อน

# %%
data1 = data.drop(127)

# %%
data2 = data1.drop(165)

# %%
data3 = data2.drop(157)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(data3['Weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c4891824340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c4891824940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c4891826aa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c4891824f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c4891825240>],
#  'means': []}

# %%
plt.boxplot(data3['ส่วนสูง'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c4891a43700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c4891a43d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c4891a43520>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c4891a424d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c4891a42770>],
#  'means': []}

# %%
plt.boxplot(data3['BMI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c488f728d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c488f729270>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c488f728a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c488f7297b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c488f729a50>],
#  'means': []}

# %%
data3.isnull().sum()
# Out:
# No                          0
# วันที่                      0
# เพศ                         0
# อายุ                        0
# Weight                      0
# ส่วนสูง                     0
# BMI                         0
# พื้นที่ทำแบบสอบถาม          0
# เวลา                        0
# Temp                        0
# Globe temp                  0
# %RH                         0
# V (m/s)                     0
# วงเล็บ 1                    0
# สมการหลัง บวก               0
# วงเล็บ 2                    0
# ยกกำลัง 1 ส่วน 4/ 0.25      0
# ลบ 273.15                   0
# Thermal acceptance          0
# -3                        190
# -2                        186
# -1                        151
# 0                         133
# +1                        138
# +2                        168
# +3                        174
# Thermal sensation Vote      0
# อุณหภูมิ                    0
# ความชื้น                    0
# กระแสลม                     0
# ความแรงของแสงแดด            0
# ...

# %%
data3.shape
# Out:
# (190, 37)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data3.describe()
# Out:
#                No        อายุ      Weight     ส่วนสูง         BMI        Temp  \
# count  190.000000  190.000000  190.000000  190.000000  190.000000  190.000000
# mean    96.152632   30.536842   68.131579  167.300000   24.237014   30.860526
# std     55.848083   11.880633   21.725769    9.781177    6.924044    2.310997
# min      1.000000   20.000000   41.000000  144.000000   16.015625   27.200000
# 25%     48.250000   25.000000   49.000000  158.250000   19.146722   29.100000
# 50%     95.500000   27.000000   63.000000  169.000000   22.222333   30.800000
# 75%    143.750000   35.750000   75.000000  173.000000   27.451280   32.700000
# max    193.000000   70.000000  120.000000  187.000000   38.019565   35.600000
#
#        Globe temp         %RH     V (m/s)      วงเล็บ 1  ...    อุณหภูมิ  \
# count  190.000000  190.000000  190.000000  1.900000e+02  ...  190.000000
# mean    31.501053   48.602105    0.265974  8.617410e+09  ...    2.542105
# ...

# %%
data3.describe(include=np.object)
# Out:
# <ipython-input-22-640c19389924>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data3.describe(include=np.object)
#             วันที่  เพศ    พื้นที่ทำแบบสอบถาม    เวลา Thermal acceptance
# count          190  190                   190  190.00                190
# unique           4    2                     6   46.00                  2
# top     13/05/2023  ชาย  ภายนอก/ มีหลังคาคลุม   16.26             Accept
# freq            63  122                   107    9.00                169

# %%
data3.Weight.describe()
# Out:
# count    190.000000
# mean      68.131579
# std       21.725769
# min       41.000000
# 25%       49.000000
# 50%       63.000000
# 75%       75.000000
# max      120.000000
# Name: Weight, dtype: float64

# %%
data3.ส่วนสูง.describe()
# Out:
# count    190.000000
# mean     167.300000
# std        9.781177
# min      144.000000
# 25%      158.250000
# 50%      169.000000
# 75%      173.000000
# max      187.000000
# Name: ส่วนสูง, dtype: float64

# %%
data3.BMI.describe()
# Out:
# count    190.000000
# mean      24.237014
# std        6.924044
# min       16.015625
# 25%       19.146722
# 50%       22.222333
# 75%       27.451280
# max       38.019565
# Name: BMI, dtype: float64

# %%
data3.อายุ.describe()
# Out:
# count    190.000000
# mean      30.536842
# std       11.880633
# min       20.000000
# 25%       25.000000
# 50%       27.000000
# 75%       35.750000
# max       70.000000
# Name: อายุ, dtype: float64

# %% [markdown]
# ##records ที่เป็นผู้ชาย จากทั้งหมด

# %%
data3[data3['เพศ']=='ชาย']
# Out:
#       No               วันที่  เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00  ชาย    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00  ชาย    36    71.0    175.0  23.183673
# 3      4  2022-12-28 00:00:00  ชาย    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00  ชาย    28   118.0    187.0  33.744173
# 5      6  2022-12-28 00:00:00  ชาย    27    49.0    169.0  17.156262
# ..   ...                  ...  ...   ...     ...      ...        ...
# 182  183           13/05/2023  ชาย    25    81.0    181.0  24.724520
# 187  188           13/05/2023  ชาย    27    72.0    171.0  24.622961
# 188  189           13/05/2023  ชาย    37    88.0    180.0  27.160494
# 190  191           13/05/2023  ชาย    27    47.0    169.0  16.456006
# 191  192           13/05/2023  ชาย    57    68.0    171.0  23.255019
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %% [markdown]
# ##records ที่เป็นผู้หญิง จากทั้งหมด

# %%
data3[data3['เพศ']=='หญิง']
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 2      3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 6      7  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 14    15  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 16    17  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 20    21  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# ..   ...                  ...   ...   ...     ...      ...        ...
# 184  185           13/05/2023  หญิง    62    45.0    144.0  21.701389
# 185  186           13/05/2023  หญิง    35    65.0    157.0  26.370238
# 186  187           13/05/2023  หญิง    62    54.0    150.0  24.000000
# 189  190           13/05/2023  หญิง    23    47.0    159.0  18.591037
# 192  193           13/05/2023  หญิง    64    47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %% [markdown]
# ##แทนค่าลักษณะของคำที่เหมือนกัน

# %%
set(data3['พื้นที่ทำแบบสอบถาม'])
# Out:
# {'ภายนอก / ใต้ร่มไม้',
#  'ภายนอก กลางแจ้ง',
#  'ภายนอก/ กลางแจ้ง',
#  'ภายนอก/ มีหลังคาคลุม',
#  'ภายใต้ร่มไม้',
#  'ภายใต้อาคาร'}

# %%
data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายใต้ร่มไม้'] = 'ภายนอก / ใต้ร่มไม้'
data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก กลางแจ้ง'] = 'ภายนอก/ กลางแจ้ง'
# Out:
# <ipython-input-21-9efe923acf1c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายใต้ร่มไม้'] = 'ภายนอก / ใต้ร่มไม้'
# <ipython-input-21-9efe923acf1c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก กลางแจ้ง'] = 'ภายนอก/ กลางแจ้ง'

# %%
set(data3['พื้นที่ทำแบบสอบถาม'])
# Out:
# {'ภายนอก / ใต้ร่มไม้',
#  'ภายนอก/ กลางแจ้ง',
#  'ภายนอก/ มีหลังคาคลุม',
#  'ภายใต้อาคาร'}

# %% [markdown]
# ##เปลี่ยนวันที่เป็น datetime

# %%
set(data3['วันที่'])
# Out:
# {'13/05/2023',
#  datetime.datetime(2022, 12, 28, 0, 0),
#  datetime.datetime(2023, 1, 6, 0, 0),
#  datetime.datetime(2023, 1, 8, 0, 0)}

# %%
data3['วันที่'] = pd.to_datetime(data3.วันที่)
# Out:
# <ipython-input-24-d6c7cf761fc2>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data3['วันที่'] = pd.to_datetime(data3.วันที่)

# %%
set(data3['วันที่'])
# Out:
# {Timestamp('2022-12-28 00:00:00'),
#  Timestamp('2023-01-06 00:00:00'),
#  Timestamp('2023-01-08 00:00:00'),
#  Timestamp('2023-05-13 00:00:00')}

# %% [markdown]
# #Visualizations

# %%
import seaborn as sns

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %% [markdown]
# ##plot แสดงเพศและอายุเฉลี่ยของผู้ตอบแบบสอบถาม

# %%
data3.groupby('เพศ').mean()
# Out:
# <ipython-input-29-46ad3f32705a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data3.groupby('เพศ').mean()
#               No       อายุ     Weight     ส่วนสูง        BMI       Temp  \
# เพศ
# ชาย    82.385246  28.500000  70.991803  173.303279  23.343620  30.308197
# หญิง  120.852941  34.191176  63.000000  156.529412  25.839867  31.851471
#
#       Globe temp        %RH   V (m/s)      วงเล็บ 1  ...  อุณหภูมิ  ความชื้น  \
# เพศ                                                  ...
# ชาย    30.940984  46.455738  0.272787  8.553826e+09  ...  2.254098  1.909836
# หญิง   32.505882  52.452941  0.253750  8.731485e+09  ...  3.058824  2.073529
#
#        กระแสลม  ความแรงของแสงแดด  เหงื่อบริเวณผิวหนัง  ความร้อน  ความชื้น.1  \
# เพศ
# ...

# %%
data31 = data3.groupby('เพศ').mean().reset_index()[['เพศ','อายุ']]
data31.sort_values(by=['อายุ'])
# Out:
# <ipython-input-30-1c1ffe577ac4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data31 = data3.groupby('เพศ').mean().reset_index()[['เพศ','อายุ']]
#     เพศ       อายุ
# 0   ชาย  28.500000
# 1  หญิง  34.191176

# %%
sns.barplot(x='เพศ', y='อายุ', data=data31)
# Out:
# <Axes: xlabel='เพศ', ylabel='อายุ'>

# %% [markdown]
# ##histogram อายุของแต่ละเพศ แสดงให้เห็นภาพรวม ค่าสูง ค่าต่ำ ค่ากลาง การกระจาย

# %%
sns.histplot(data=data3, x="อายุ", hue="เพศ", multiple="dodge", shrink=1, palette="magma")
# Out:
# <Axes: xlabel='อายุ', ylabel='Count'>

# %%
sns.histplot(data=data3, x="อายุ", hue="เพศ", multiple="stack", palette="magma")
# Out:
# <Axes: xlabel='อายุ', ylabel='Count'>

# %% [markdown]
# ##plot แสดงเพศและอุณหภูมิเฉลี่ยของผู้ตอบแบบสอบถาม

# %%
data3.groupby('เพศ').mean()
# Out:
# <ipython-input-39-46ad3f32705a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data3.groupby('เพศ').mean()
#               No       อายุ     Weight     ส่วนสูง        BMI       Temp  \
# เพศ
# ชาย    82.385246  28.500000  70.991803  173.303279  23.343620  30.308197
# หญิง  120.852941  34.191176  63.000000  156.529412  25.839867  31.851471
#
#       Globe temp        %RH   V (m/s)      วงเล็บ 1  ...  อุณหภูมิ  ความชื้น  \
# เพศ                                                  ...
# ชาย    30.940984  46.455738  0.272787  8.553826e+09  ...  2.254098  1.909836
# หญิง   32.505882  52.452941  0.253750  8.731485e+09  ...  3.058824  2.073529
#
#        กระแสลม  ความแรงของแสงแดด  เหงื่อบริเวณผิวหนัง  ความร้อน  ความชื้น.1  \
# เพศ
# ...

# %%
data32 = data3.groupby('เพศ').mean().reset_index()[['เพศ','Temp']]
data32.sort_values(by=['Temp'])
# Out:
# <ipython-input-40-2567d7d1b97b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data32 = data3.groupby('เพศ').mean().reset_index()[['เพศ','Temp']]
#     เพศ       Temp
# 0   ชาย  30.308197
# 1  หญิง  31.851471

# %%
sns.barplot(x='เพศ', y='Temp', data=data32)
# Out:
# <Axes: xlabel='เพศ', ylabel='Temp'>

# %% [markdown]
# ##histogram อุณหภูมิบริเวณที่ทำแบบสอบถามของแต่ละเพศ แสดงให้เห็นภาพรวม ค่าสูง ค่าต่ำ ค่ากลาง การกระจาย

# %%
sns.histplot(data=data3, x="Temp", hue="เพศ", multiple="dodge", shrink=1, palette="viridis")
# Out:
# <Axes: xlabel='Temp', ylabel='Count'>

# %%
sns.histplot(data=data3, x="Temp", hue="เพศ", multiple="stack", palette="viridis")
# Out:
# <Axes: xlabel='Temp', ylabel='Count'>

# %% [markdown]
# ##plot แสดงพื้นที่ทำแบบสอบถามและอุณหภูมิเฉลี่ยของผู้ตอบแบบสอบถาม

# %%
data3.groupby('พื้นที่ทำแบบสอบถาม').mean()
# Out:
# <ipython-input-44-4bcfa94405ad>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data3.groupby('พื้นที่ทำแบบสอบถาม').mean()
#                               No       อายุ     Weight     ส่วนสูง        BMI  \
# พื้นที่ทำแบบสอบถาม
# ภายนอก / ใต้ร่มไม้    138.733333  30.866667  60.333333  163.066667  22.858977
# ภายนอก/ กลางแจ้ง      101.888889  25.777778  67.888889  169.777778  23.445335
# ภายนอก/ มีหลังคาคลุม   61.046729  26.364486  72.364486  169.364486  25.157033
# ภายใต้อาคาร           156.440000  41.080000  61.500000  163.260000  22.966587
#
#                            Temp  Globe temp        %RH   V (m/s)  \
# พื้นที่ทำแบบสอบถาม
# ภายนอก / ใต้ร่มไม้    32.100000   32.646667  50.213333  0.240667
# ภายนอก/ กลางแจ้ง      31.250000   31.544444  47.188889  0.215278
# ...

# %%
data33 = data3.groupby('พื้นที่ทำแบบสอบถาม').mean().reset_index()[['พื้นที่ทำแบบสอบถาม','Temp']]
data33.sort_values(by=['Temp'])
# Out:
# <ipython-input-46-380a201e1de6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data33 = data3.groupby('พื้นที่ทำแบบสอบถาม').mean().reset_index()[['พื้นที่ทำแบบสอบถาม','Temp']]
#      พื้นที่ทำแบบสอบถาม       Temp
# 2  ภายนอก/ มีหลังคาคลุม  29.472897
# 1      ภายนอก/ กลางแจ้ง  31.250000
# 0    ภายนอก / ใต้ร่มไม้  32.100000
# 3           ภายใต้อาคาร  33.318000

# %%
sns.barplot(x='Temp', y='พื้นที่ทำแบบสอบถาม', data=data33)
# Out:
# <Axes: xlabel='Temp', ylabel='พื้นที่ทำแบบสอบถาม'>

# %% [markdown]
# ##histogram อุณหภูมิบริเวณที่ทำแบบสอบถามของแต่ละพื้นที่ทำแบบสอบถาม แสดงให้เห็นภาพรวม ค่าสูง ค่าต่ำ ค่ากลาง การกระจาย

# %%
sns.histplot(data=data3, x="Temp", hue="พื้นที่ทำแบบสอบถาม", multiple="dodge", shrink=1.4, palette="viridis")
# Out:
# <Axes: xlabel='Temp', ylabel='Count'>

# %%
sns.histplot(data=data3, x="Temp", hue="พื้นที่ทำแบบสอบถาม", multiple="stack", palette="viridis")
# Out:
# <Axes: xlabel='Temp', ylabel='Count'>

# %% [markdown]
# ##plot แสดงจำนวนที่ผู้ตอบแบบสอบถามที่ยอมรับสภาพอากาศและไม่ยอมรับสภาพอากาศ

# %%
count_pv_onset = data3.groupby('Thermal acceptance')[['No']].count().sort_values('No', ascending=False)
count_pv_onset
# Out:
#                      No
# Thermal acceptance
# Accept              169
# Unaccept             21

# %%
count_pv_onset.plot.pie(y='No')
# Out:
# <Axes: ylabel='No'>
